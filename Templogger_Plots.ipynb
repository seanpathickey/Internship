# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import datetime as dt

##################### Import data and change to datetime ########################################

site1 = pd.read_csv(r'C:\Users\sph0088\OneDrive - UNT System\MORA\Analysis\templogger\site1_temps.csv').dropna()
site2 = pd.read_csv(r'C:\Users\sph0088\OneDrive - UNT System\MORA\Analysis\templogger\site2_temps.csv').dropna()
site3 = pd.read_csv(r'C:\Users\sph0088\OneDrive - UNT System\MORA\Analysis\templogger\site3_temps.csv').dropna()
site4 = pd.read_csv(r'C:\Users\sph0088\OneDrive - UNT System\MORA\Analysis\templogger\site4_temps.csv').dropna()

site1['date'] = pd.to_datetime(site1['date'], format='%Y/%m/%d %H:%M')
site2['date'] = pd.to_datetime(site2['date'], format='%m/%d/%Y %H:%M')
site3['date'] = pd.to_datetime(site3['date'], format='%Y/%m/%d %H:%M')
site4['date'] = pd.to_datetime(site4['date'], format='%Y/%m/%d %H:%M')


site1['date'] = site1['date'].dt.floor('H') #Drops off the minutes and seconds of the time
site1 = pd.DataFrame(site1.groupby(['date'],as_index=False).mean())

site2['date'] = site2['date'].dt.floor('H') #Drops off the minutes and seconds of the time
site2 = pd.DataFrame(site2.groupby(['date'],as_index=False).mean())

site3['date'] = site3['date'].dt.floor('H') #Drops off the minutes and seconds of the time
site3 = pd.DataFrame(site3.groupby(['date'],as_index=False).mean())

site4['date'] = site4['date'].dt.floor('H') #Drops off the minutes and seconds of the time
site4 = pd.DataFrame(site4.groupby(['date'],as_index=False).mean())


df3e = pd.read_csv(r'C:\Users\sph0088\OneDrive - UNT System\MORA\Analysis\PurpleAir\3E_20200618-20200805_hourlyPDT.csv')
df3e['date'] = pd.to_datetime(df3e['date'], format='%Y/%m/%d %H')

####################### Filter for Dates ###################################################
start_date = '2020/06/21'
end_date = '2020/06/28'

site1 = site1[(site1['date'] >= start_date) & (site1['date'] <= end_date)]
site2 = site2[(site2['date'] >= start_date) & (site2['date'] <= end_date)]
site3 = site3[(site3['date'] >= start_date) & (site3['date'] <= end_date)]
site4 = site4[(site4['date'] >= start_date) & (site4['date'] <= end_date)]
df3e = df3e[(df3e['date'] >= start_date) & (df3e['date'] <= end_date)]

################### TEMP Inversion when temp increases with height ##########################
#Plot
lw = 3

plt.figure(figsize=(14,6))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%m-%d-%Y %H:%M'))
plt.gca().xaxis.set_major_locator(mdates.HourLocator(interval=8))
plt.plot(site1['date'],site1['temp_F'], label='Temp @ Low Elevation (Site 1)',linewidth=lw, zorder=1, alpha=1)
# plt.plot(site2['date'],site2['temp_F'], label='site2',linewidth=lw, zorder=2, alpha=1)
# plt.plot(site3['date'],site3['temp_F'], label = 'site3',linewidth=lw, zorder=3, alpha=1)
plt.plot(site4['date'],site4['temp_F'], label = 'Temp @ High Elevation (Site 4)',linewidth=lw, zorder=4, alpha=1)
plt.plot(df3e['date'],df3e['pm2_5_atm'], label = 'PurpleAir PM2.5',linewidth=lw, zorder=5)
plt.gcf().autofmt_xdate()
plt.title('Temperature Loggers Plotted @ Two Elevations vs. PM2.5 at Ohana: Before Opening', size=16)
plt.ylabel('PM2.5 (ug m-3)               Temperature (F)',size=14, labelpad=10)
plt.xticks(fontsize=12, rotation=30)
plt.yticks(fontsize=12)
plt.legend()
plt.grid()
# plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import datetime as dt

##################### Import data and change to datetime ########################################

site1 = pd.read_csv(r'C:\Users\sph0088\OneDrive - UNT System\MORA\Analysis\templogger\site1_temps.csv').dropna()
site2 = pd.read_csv(r'C:\Users\sph0088\OneDrive - UNT System\MORA\Analysis\templogger\site2_temps.csv').dropna()
site3 = pd.read_csv(r'C:\Users\sph0088\OneDrive - UNT System\MORA\Analysis\templogger\site3_temps.csv').dropna()
site4 = pd.read_csv(r'C:\Users\sph0088\OneDrive - UNT System\MORA\Analysis\templogger\site4_temps.csv').dropna()

site1['date'] = pd.to_datetime(site1['date'], format='%Y/%m/%d %H:%M')
site2['date'] = pd.to_datetime(site2['date'], format='%m/%d/%Y %H:%M')
site3['date'] = pd.to_datetime(site3['date'], format='%Y/%m/%d %H:%M')
site4['date'] = pd.to_datetime(site4['date'], format='%Y/%m/%d %H:%M')


site1['date'] = site1['date'].dt.floor('H') #Drops off the minutes and seconds of the time
site1 = pd.DataFrame(site1.groupby(['date'],as_index=False).mean())

site2['date'] = site2['date'].dt.floor('H') #Drops off the minutes and seconds of the time
site2 = pd.DataFrame(site2.groupby(['date'],as_index=False).mean())

site3['date'] = site3['date'].dt.floor('H') #Drops off the minutes and seconds of the time
site3 = pd.DataFrame(site3.groupby(['date'],as_index=False).mean())

site4['date'] = site4['date'].dt.floor('H') #Drops off the minutes and seconds of the time
site4 = pd.DataFrame(site4.groupby(['date'],as_index=False).mean())


df3e = pd.read_csv(r'C:\Users\sph0088\OneDrive - UNT System\MORA\Analysis\PurpleAir\3E_20200618-20200805_hourlyPDT.csv')
df3e['date'] = pd.to_datetime(df3e['date'], format='%Y/%m/%d %H')

####################### Filter for Dates ###################################################
start_date = '2020/06/28'
end_date = '2020/07/05'

site1 = site1[(site1['date'] >= start_date) & (site1['date'] <= end_date)]
site2 = site2[(site2['date'] >= start_date) & (site2['date'] <= end_date)]
site3 = site3[(site3['date'] >= start_date) & (site3['date'] <= end_date)]
site4 = site4[(site4['date'] >= start_date) & (site4['date'] <= end_date)]
df3e = df3e[(df3e['date'] >= start_date) & (df3e['date'] <= end_date)]

################### TEMP Inversion when temp increases with height ##########################
#Plot
lw = 3

plt.figure(figsize=(14,6))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%m-%d-%Y %H:%M'))
plt.gca().xaxis.set_major_locator(mdates.HourLocator(interval=8))
plt.plot(site1['date'],site1['temp_F'], label='Temp @ Low Elevation (Site 1)',linewidth=lw, zorder=1, alpha=1)
# plt.plot(site2['date'],site2['temp_F'], label='site2',linewidth=lw, zorder=2, alpha=1)
# plt.plot(site3['date'],site3['temp_F'], label = 'site3',linewidth=lw, zorder=3, alpha=1)
plt.plot(site4['date'],site4['temp_F'], label = 'Temp @ High Elevation (Site 4)',linewidth=lw, zorder=4, alpha=1)
plt.plot(df3e['date'],df3e['pm2_5_atm'], label = 'PurpleAir PM2.5',linewidth=lw, zorder=5)
plt.gcf().autofmt_xdate()
plt.title('Temperature Loggers Plotted @ Two Elevations vs. PM2.5 at Ohana: Opening Weekend', size=16)
plt.ylabel('PM2.5 (ug m-3)               Temperature (F)',size=14, labelpad=10)
plt.xticks(fontsize=12, rotation=30)
plt.yticks(fontsize=12)
plt.legend()
plt.grid()
# plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import datetime as dt

##################### Import data and change to datetime ########################################

site1 = pd.read_csv(r'C:\Users\sph0088\OneDrive - UNT System\MORA\Analysis\templogger\site1_temps.csv').dropna()
site2 = pd.read_csv(r'C:\Users\sph0088\OneDrive - UNT System\MORA\Analysis\templogger\site2_temps.csv').dropna()
site3 = pd.read_csv(r'C:\Users\sph0088\OneDrive - UNT System\MORA\Analysis\templogger\site3_temps.csv').dropna()
site4 = pd.read_csv(r'C:\Users\sph0088\OneDrive - UNT System\MORA\Analysis\templogger\site4_temps.csv').dropna()

site1['date'] = pd.to_datetime(site1['date'], format='%Y/%m/%d %H:%M')
site2['date'] = pd.to_datetime(site2['date'], format='%m/%d/%Y %H:%M')
site3['date'] = pd.to_datetime(site3['date'], format='%Y/%m/%d %H:%M')
site4['date'] = pd.to_datetime(site4['date'], format='%Y/%m/%d %H:%M')


site1['date'] = site1['date'].dt.floor('H') #Drops off the minutes and seconds of the time
site1 = pd.DataFrame(site1.groupby(['date'],as_index=False).mean())

site2['date'] = site2['date'].dt.floor('H') #Drops off the minutes and seconds of the time
site2 = pd.DataFrame(site2.groupby(['date'],as_index=False).mean())

site3['date'] = site3['date'].dt.floor('H') #Drops off the minutes and seconds of the time
site3 = pd.DataFrame(site3.groupby(['date'],as_index=False).mean())

site4['date'] = site4['date'].dt.floor('H') #Drops off the minutes and seconds of the time
site4 = pd.DataFrame(site4.groupby(['date'],as_index=False).mean())


df3e = pd.read_csv(r'C:\Users\sph0088\OneDrive - UNT System\MORA\Analysis\PurpleAir\3E_20200618-20200805_hourlyPDT.csv')
df3e['date'] = pd.to_datetime(df3e['date'], format='%Y/%m/%d %H')

####################### Filter for Dates ###################################################
start_date = '2020/07/05'
end_date = '2020/07/12'

site1 = site1[(site1['date'] >= start_date) & (site1['date'] <= end_date)]
site2 = site2[(site2['date'] >= start_date) & (site2['date'] <= end_date)]
site3 = site3[(site3['date'] >= start_date) & (site3['date'] <= end_date)]
site4 = site4[(site4['date'] >= start_date) & (site4['date'] <= end_date)]
df3e = df3e[(df3e['date'] >= start_date) & (df3e['date'] <= end_date)]

################### TEMP Inversion when temp increases with height ##########################
#Plot
lw = 3

plt.figure(figsize=(14,6))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%m-%d-%Y %H:%M'))
plt.gca().xaxis.set_major_locator(mdates.HourLocator(interval=8))
plt.plot(site1['date'],site1['temp_F'], label='Temp @ Low Elevation (Site 1)',linewidth=lw, zorder=1, alpha=1)
# plt.plot(site2['date'],site2['temp_F'], label='site2',linewidth=lw, zorder=2, alpha=1)
# plt.plot(site3['date'],site3['temp_F'], label = 'site3',linewidth=lw, zorder=3, alpha=1)
plt.plot(site4['date'],site4['temp_F'], label = 'Temp @ High Elevation (Site 4)',linewidth=lw, zorder=4, alpha=1)
plt.plot(df3e['date'],df3e['pm2_5_atm'], label = 'PurpleAir PM2.5',linewidth=lw, zorder=5)
plt.gcf().autofmt_xdate()
plt.title('Temperature Loggers Plotted @ Two Elevations vs. PM2.5 at Ohana: After Opening', size=16)
plt.ylabel('PM2.5 (ug m-3)               Temperature (F)',size=14, labelpad=10)
plt.xticks(fontsize=12, rotation=30)
plt.yticks(fontsize=12)
plt.legend()
plt.grid()
# plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import datetime as dt

##################### Import data and change to datetime ########################################

site1 = pd.read_csv(r'C:\Users\sph0088\OneDrive - UNT System\MORA\Analysis\templogger\site1_temps.csv').dropna()
site2 = pd.read_csv(r'C:\Users\sph0088\OneDrive - UNT System\MORA\Analysis\templogger\site2_temps.csv').dropna()
site3 = pd.read_csv(r'C:\Users\sph0088\OneDrive - UNT System\MORA\Analysis\templogger\site3_temps.csv').dropna()
site4 = pd.read_csv(r'C:\Users\sph0088\OneDrive - UNT System\MORA\Analysis\templogger\site4_temps.csv').dropna()

site1['date'] = pd.to_datetime(site1['date'], format='%Y/%m/%d %H:%M')
site2['date'] = pd.to_datetime(site2['date'], format='%m/%d/%Y %H:%M')
site3['date'] = pd.to_datetime(site3['date'], format='%Y/%m/%d %H:%M')
site4['date'] = pd.to_datetime(site4['date'], format='%Y/%m/%d %H:%M')


site1['date'] = site1['date'].dt.floor('H') #Drops off the minutes and seconds of the time
site1 = pd.DataFrame(site1.groupby(['date'],as_index=False).mean())

site2['date'] = site2['date'].dt.floor('H') #Drops off the minutes and seconds of the time
site2 = pd.DataFrame(site2.groupby(['date'],as_index=False).mean())

site3['date'] = site3['date'].dt.floor('H') #Drops off the minutes and seconds of the time
site3 = pd.DataFrame(site3.groupby(['date'],as_index=False).mean())

site4['date'] = site4['date'].dt.floor('H') #Drops off the minutes and seconds of the time
site4 = pd.DataFrame(site4.groupby(['date'],as_index=False).mean())


df3e = pd.read_csv(r'C:\Users\sph0088\OneDrive - UNT System\MORA\Analysis\PurpleAir\3E_20200618-20200805_hourlyPDT.csv')
df3e['date'] = pd.to_datetime(df3e['date'], format='%Y/%m/%d %H')

####################### Filter for Dates ###################################################
start_date = '2020/07/12'
end_date = '2020/07/19'

site1 = site1[(site1['date'] >= start_date) & (site1['date'] <= end_date)]
site2 = site2[(site2['date'] >= start_date) & (site2['date'] <= end_date)]
site3 = site3[(site3['date'] >= start_date) & (site3['date'] <= end_date)]
site4 = site4[(site4['date'] >= start_date) & (site4['date'] <= end_date)]
df3e = df3e[(df3e['date'] >= start_date) & (df3e['date'] <= end_date)]

################### TEMP Inversion when temp increases with height ##########################
#Plot
lw = 3

plt.figure(figsize=(14,6))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%m-%d-%Y %H:%M'))
plt.gca().xaxis.set_major_locator(mdates.HourLocator(interval=8))
plt.plot(site1['date'],site1['temp_F'], label='Temp @ Low Elevation (Site 1)',linewidth=lw, zorder=1, alpha=1)
# plt.plot(site2['date'],site2['temp_F'], label='site2',linewidth=lw, zorder=2, alpha=1)
# plt.plot(site3['date'],site3['temp_F'], label = 'site3',linewidth=lw, zorder=3, alpha=1)
plt.plot(site4['date'],site4['temp_F'], label = 'Temp @ High Elevation (Site 4)',linewidth=lw, zorder=4, alpha=1)
plt.plot(df3e['date'],df3e['pm2_5_atm'], label = 'PurpleAir PM2.5',linewidth=lw, zorder=5)
plt.gcf().autofmt_xdate()
plt.title('Temperature Loggers Plotted @ Two Elevations vs. PM2.5 at Ohana: After Opening', size=16)
plt.ylabel('PM2.5 (ug m-3)               Temperature (F)',size=14, labelpad=10)
plt.xticks(fontsize=12, rotation=30)
plt.yticks(fontsize=12)
plt.legend()
plt.grid()
# plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import datetime as dt

##################### Import data and change to datetime ########################################

site1 = pd.read_csv(r'C:\Users\sph0088\OneDrive - UNT System\MORA\Analysis\templogger\site1_temps.csv').dropna()
site2 = pd.read_csv(r'C:\Users\sph0088\OneDrive - UNT System\MORA\Analysis\templogger\site2_temps.csv').dropna()
site3 = pd.read_csv(r'C:\Users\sph0088\OneDrive - UNT System\MORA\Analysis\templogger\site3_temps.csv').dropna()
site4 = pd.read_csv(r'C:\Users\sph0088\OneDrive - UNT System\MORA\Analysis\templogger\site4_temps.csv').dropna()

site1['date'] = pd.to_datetime(site1['date'], format='%Y/%m/%d %H:%M')
site2['date'] = pd.to_datetime(site2['date'], format='%m/%d/%Y %H:%M')
site3['date'] = pd.to_datetime(site3['date'], format='%Y/%m/%d %H:%M')
site4['date'] = pd.to_datetime(site4['date'], format='%Y/%m/%d %H:%M')


site1['date'] = site1['date'].dt.floor('H') #Drops off the minutes and seconds of the time
site1 = pd.DataFrame(site1.groupby(['date'],as_index=False).mean())

site2['date'] = site2['date'].dt.floor('H') #Drops off the minutes and seconds of the time
site2 = pd.DataFrame(site2.groupby(['date'],as_index=False).mean())

site3['date'] = site3['date'].dt.floor('H') #Drops off the minutes and seconds of the time
site3 = pd.DataFrame(site3.groupby(['date'],as_index=False).mean())

site4['date'] = site4['date'].dt.floor('H') #Drops off the minutes and seconds of the time
site4 = pd.DataFrame(site4.groupby(['date'],as_index=False).mean())


df3e = pd.read_csv(r'C:\Users\sph0088\OneDrive - UNT System\MORA\Analysis\PurpleAir\3E_20200618-20200805_hourlyPDT.csv')
df3e['date'] = pd.to_datetime(df3e['date'], format='%Y/%m/%d %H')

####################### Filter for Dates ###################################################
start_date = '2020/07/19'
end_date = '2020/07/26'

site1 = site1[(site1['date'] >= start_date) & (site1['date'] <= end_date)]
site2 = site2[(site2['date'] >= start_date) & (site2['date'] <= end_date)]
site3 = site3[(site3['date'] >= start_date) & (site3['date'] <= end_date)]
site4 = site4[(site4['date'] >= start_date) & (site4['date'] <= end_date)]
df3e = df3e[(df3e['date'] >= start_date) & (df3e['date'] <= end_date)]

################### TEMP Inversion when temp increases with height ##########################
#Plot
lw = 3

plt.figure(figsize=(14,6))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%m-%d-%Y %H:%M'))
plt.gca().xaxis.set_major_locator(mdates.HourLocator(interval=8))
plt.plot(site1['date'],site1['temp_F'], label='Temp @ Low Elevation (Site 1)',linewidth=lw, zorder=1, alpha=1)
# plt.plot(site2['date'],site2['temp_F'], label='site2',linewidth=lw, zorder=2, alpha=1)
# plt.plot(site3['date'],site3['temp_F'], label = 'site3',linewidth=lw, zorder=3, alpha=1)
plt.plot(site4['date'],site4['temp_F'], label = 'Temp @ High Elevation (Site 4)',linewidth=lw, zorder=4, alpha=1)
plt.plot(df3e['date'],df3e['pm2_5_atm'], label = 'PurpleAir PM2.5',linewidth=lw, zorder=5)
plt.gcf().autofmt_xdate()
plt.title('Temperature Loggers Plotted @ Two Elevations vs. PM2.5 at Ohana: After Opening', size=16)
plt.ylabel('PM2.5 (ug m-3)               Temperature (F)',size=14, labelpad=10)
plt.xticks(fontsize=12, rotation=30)
plt.yticks(fontsize=12)
plt.legend()
plt.grid()
# plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import datetime as dt

##################### Import data and change to datetime ########################################

site1 = pd.read_csv(r'C:\Users\sph0088\OneDrive - UNT System\MORA\Analysis\templogger\site1_temps.csv').dropna()
site2 = pd.read_csv(r'C:\Users\sph0088\OneDrive - UNT System\MORA\Analysis\templogger\site2_temps.csv').dropna()
site3 = pd.read_csv(r'C:\Users\sph0088\OneDrive - UNT System\MORA\Analysis\templogger\site3_temps.csv').dropna()
site4 = pd.read_csv(r'C:\Users\sph0088\OneDrive - UNT System\MORA\Analysis\templogger\site4_temps.csv').dropna()

site1['date'] = pd.to_datetime(site1['date'], format='%Y/%m/%d %H:%M')
site2['date'] = pd.to_datetime(site2['date'], format='%m/%d/%Y %H:%M')
site3['date'] = pd.to_datetime(site3['date'], format='%Y/%m/%d %H:%M')
site4['date'] = pd.to_datetime(site4['date'], format='%Y/%m/%d %H:%M')


site1['date'] = site1['date'].dt.floor('H') #Drops off the minutes and seconds of the time
site1 = pd.DataFrame(site1.groupby(['date'],as_index=False).mean())

site2['date'] = site2['date'].dt.floor('H') #Drops off the minutes and seconds of the time
site2 = pd.DataFrame(site2.groupby(['date'],as_index=False).mean())

site3['date'] = site3['date'].dt.floor('H') #Drops off the minutes and seconds of the time
site3 = pd.DataFrame(site3.groupby(['date'],as_index=False).mean())

site4['date'] = site4['date'].dt.floor('H') #Drops off the minutes and seconds of the time
site4 = pd.DataFrame(site4.groupby(['date'],as_index=False).mean())


df3e = pd.read_csv(r'C:\Users\sph0088\OneDrive - UNT System\MORA\Analysis\PurpleAir\3E_20200618-20200805_hourlyPDT.csv')
df3e['date'] = pd.to_datetime(df3e['date'], format='%Y/%m/%d %H')

####################### Filter for Dates ###################################################
start_date = '2020/07/26'
end_date = '2020/08/02'

site1 = site1[(site1['date'] >= start_date) & (site1['date'] <= end_date)]
site2 = site2[(site2['date'] >= start_date) & (site2['date'] <= end_date)]
site3 = site3[(site3['date'] >= start_date) & (site3['date'] <= end_date)]
site4 = site4[(site4['date'] >= start_date) & (site4['date'] <= end_date)]
df3e = df3e[(df3e['date'] >= start_date) & (df3e['date'] <= end_date)]

################### TEMP Inversion when temp increases with height ##########################
#Plot
lw = 3

plt.figure(figsize=(14,6))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%m-%d-%Y %H:%M'))
plt.gca().xaxis.set_major_locator(mdates.HourLocator(interval=8))
plt.plot(site1['date'],site1['temp_F'], label='Temp @ Low Elevation (Site 1)',linewidth=lw, zorder=1, alpha=1)
# plt.plot(site2['date'],site2['temp_F'], label='site2',linewidth=lw, zorder=2, alpha=1)
# plt.plot(site3['date'],site3['temp_F'], label = 'site3',linewidth=lw, zorder=3, alpha=1)
plt.plot(site4['date'],site4['temp_F'], label = 'Temp @ High Elevation (Site 4)',linewidth=lw, zorder=4, alpha=1)
plt.plot(df3e['date'],df3e['pm2_5_atm'], label = 'PurpleAir PM2.5',linewidth=lw, zorder=5)
plt.gcf().autofmt_xdate()
plt.title('Temperature Loggers Plotted @ Two Elevations vs. PM2.5 at Ohana: After Opening', size=16)
plt.ylabel('PM2.5 (ug m-3)               Temperature (F)',size=14, labelpad=10)
plt.xticks(fontsize=12, rotation=30)
plt.yticks(fontsize=12)
plt.legend(loc='center')
plt.grid()
# plt.show()

# %%
import matplotlib.dates as mdates
import datetime as dt

##################### Import data and change to datetime ########################################

site1 = pd.read_csv(r'C:\Users\sph0088\OneDrive - UNT System\MORA\Analysis\templogger\site1_temps.csv').dropna()
site2 = pd.read_csv(r'C:\Users\sph0088\OneDrive - UNT System\MORA\Analysis\templogger\site2_temps.csv').dropna()
site3 = pd.read_csv(r'C:\Users\sph0088\OneDrive - UNT System\MORA\Analysis\templogger\site3_temps.csv').dropna()
site4 = pd.read_csv(r'C:\Users\sph0088\OneDrive - UNT System\MORA\Analysis\templogger\site4_temps.csv').dropna()

site1['date'] = pd.to_datetime(site1['date'], format='%Y/%m/%d %H:%M')
site2['date'] = pd.to_datetime(site2['date'], format='%m/%d/%Y %H:%M')
site3['date'] = pd.to_datetime(site3['date'], format='%Y/%m/%d %H:%M')
site4['date'] = pd.to_datetime(site4['date'], format='%Y/%m/%d %H:%M')


site1['date'] = site1['date'].dt.floor('H') #Drops off the minutes and seconds of the time
site1 = pd.DataFrame(site1.groupby(['date'],as_index=False).mean())

site2['date'] = site2['date'].dt.floor('H') #Drops off the minutes and seconds of the time
site2 = pd.DataFrame(site2.groupby(['date'],as_index=False).mean())

site3['date'] = site3['date'].dt.floor('H') #Drops off the minutes and seconds of the time
site3 = pd.DataFrame(site3.groupby(['date'],as_index=False).mean())

site4['date'] = site4['date'].dt.floor('H') #Drops off the minutes and seconds of the time
site4 = pd.DataFrame(site4.groupby(['date'],as_index=False).mean())


df3e = pd.read_csv(r'C:\Users\sph0088\OneDrive - UNT System\MORA\Analysis\PurpleAir\3E_20200618-20200805_hourlyPDT.csv')
df3e['date'] = pd.to_datetime(df3e['date'], format='%Y/%m/%d %H')

####################### Filter for Dates ###################################################
start_date = '2020/08/02'
end_date = '2020/08/04'

site1 = site1[(site1['date'] >= start_date) & (site1['date'] <= end_date)]
site2 = site2[(site2['date'] >= start_date) & (site2['date'] <= end_date)]
site3 = site3[(site3['date'] >= start_date) & (site3['date'] <= end_date)]
site4 = site4[(site4['date'] >= start_date) & (site4['date'] <= end_date)]
df3e = df3e[(df3e['date'] >= start_date) & (df3e['date'] <= end_date)]

################### TEMP Inversion when temp increases with height ##########################
#Plot
lw = 3

plt.figure(figsize=(6,10))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%m-%d-%Y %H:%M'))
plt.gca().xaxis.set_major_locator(mdates.HourLocator(interval=8))
plt.plot(site1['date'],site1['temp_F'], label='Temp @ Low Elevation (Site 1)',linewidth=lw, zorder=1, alpha=1)
# plt.plot(site2['date'],site2['temp_F'], label='site2',linewidth=lw, zorder=2, alpha=1)
# plt.plot(site3['date'],site3['temp_F'], label = 'site3',linewidth=lw, zorder=3, alpha=1)
plt.plot(site4['date'],site4['temp_F'], label = 'Temp @ High Elevation (Site 4)',linewidth=lw, zorder=4, alpha=1)
plt.plot(df3e['date'],df3e['pm2_5_atm'], label = 'PurpleAir PM2.5',linewidth=lw, zorder=5)
plt.gcf().autofmt_xdate()
plt.title('', size=16)
plt.ylabel('PM2.5 (ug m-3)                                 Temperature (F)',size=16, labelpad=10)
plt.xticks(fontsize=14, rotation=30)
plt.yticks(fontsize=14)
plt.legend()
plt.grid()
# plt.show()
