# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import numpy as np
import datetime as dt

df3e = pd.read_csv(r'C:\Users\sph0088\OneDrive - UNT System\MORA\Analysis\E-BAM\EBAM_PA3E_hourly.csv')
df3e['date'] = pd.to_datetime(df3e['date'], format='%Y/%m/%d %H')

# mask = (df3e['date'] > '2020/07/24') & (df3e['date'] <= '2020/08/04')
df3e = df3e[(df3e['date'] >= '2020/06/18 15:00') & (df3e['date'] <= '2020/07/02')]

# mask = (df3e['date'] > '2020/07/24') & (df3e['date'] <= '2020/08/04')
# df3e = df3e.loc[mask]

plt.figure(figsize=(14,6))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d %H:%M'))
plt.gca().xaxis.set_major_locator(mdates.HourLocator(interval=24))
plt.plot(df3e['date'],df3e['EBAM_pm25'], label='EBAM')
plt.plot(df3e['date'],df3e['PA_pm25_avg'], label = 'PA-3E')
plt.gcf().autofmt_xdate()
plt.title('Hourly E-BAM Concentrations vs 1-Purple Air at Ohana Prior to Opening: 06/18/2020-07/02/2020', size=15, pad=10)
plt.ylabel('PM2.5 (ug m-3)',size=14, labelpad=10)
plt.xticks(fontsize=12, rotation=30)
plt.yticks(fontsize=12)
plt.legend(fontsize=12)
plt.grid(color='grey', linestyle='-', linewidth=0.5, alpha=0.5)
# plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import numpy as np
import datetime as dt

df3e = pd.read_csv(r'C:\Users\sph0088\OneDrive - UNT System\MORA\Analysis\E-BAM\EBAM_PA3E_hourly.csv')
df3e['date'] = pd.to_datetime(df3e['date'], format='%Y/%m/%d %H')

# mask = (df3e['date'] > '2020/07/24') & (df3e['date'] <= '2020/08/04')
df3e = df3e[(df3e['date'] > '2020/07/24 16:00') & (df3e['date'] <= '2020/08/04')]

# mask = (df3e['date'] > '2020/07/24') & (df3e['date'] <= '2020/08/04')
# df3e = df3e.loc[mask]

plt.figure(figsize=(20,6))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d %H:%M'))
plt.gca().xaxis.set_major_locator(mdates.HourLocator(interval=24))
plt.plot(df3e['date'],df3e['EBAM_pm25'], label='EBAM')
plt.plot(df3e['date'],df3e['PA_pm25_avg'], label = 'PA-3E')
plt.gcf().autofmt_xdate()
plt.title('Hourly E-BAM Concentrations vs Two PurpleAir Sensors at Ohana: 07/24/2020-08/03/2020', size=15, pad=10)
plt.ylabel('PM2.5 (ug m-3)',size=14, labelpad=10)
plt.xticks(fontsize=12, rotation=30)
plt.yticks(fontsize=12)
plt.legend(fontsize=12)
plt.grid(color='grey', linestyle='-', linewidth=0.5, alpha=0.5)
# plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import numpy as np
import datetime as dt

#Data
df1b = pd.read_csv(r'C:\Users\sph0088\OneDrive - UNT System\MORA\Analysis\E-BAM\EBAM_PA1B_hourly.csv')
df1b['date'] = pd.to_datetime(df1b['date'], format='%Y/%m/%d %H')
df3e = pd.read_csv(r'C:\Users\sph0088\OneDrive - UNT System\MORA\Analysis\E-BAM\EBAM_PA3E_hourly.csv')
df3e['date'] = pd.to_datetime(df3e['date'], format='%Y/%m/%d %H')


#Filter for Dates
df3e = df3e[(df3e['date'] > '2020/07/24 16:00') & (df3e['date'] <= '2020/08/04')]
df1b = df1b[(df1b['date'] > '2020/07/24 16:00') & (df1b['date'] <= '2020/08/04')]

#Plot
lw = 2

plt.figure(figsize=(14,6))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d %H:%M'))
plt.gca().xaxis.set_major_locator(mdates.HourLocator(interval=24))
plt.plot(df1b['date'],df1b['EBAM_pm25'], label='EBAM',linewidth=lw, zorder=1)
plt.plot(df3e['date'],df3e['PA_pm25_avg'], label = 'PA-3E',linewidth=lw, zorder=3)
plt.plot(df1b['date'],df1b['PA_pm25_avg'], label = 'PA-1B', linewidth=lw, zorder=2) #Z order changes the order in which the lines are rendered
plt.gcf().autofmt_xdate()
plt.title('Hourly E-BAM Concentrations vs 2-PurpleAir Sensors at Ohana: 07/24/2020-08/03/2020', size=15, pad=10)
plt.ylabel('PM2.5 (ug m-3)',size=14, labelpad=10)
plt.xticks(fontsize=12, rotation=30)
plt.yticks(fontsize=12)
plt.legend(fontsize=12)
plt.grid(color='grey', linestyle='-', linewidth=0.5, alpha=0.5)
# plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import numpy as np
import datetime as dt

#Data
df3e = pd.read_csv(r'C:\Users\sph0088\OneDrive - UNT System\MORA\Analysis\E-BAM\EBAM_PA3E_hourly.csv')
df3e['date'] = pd.to_datetime(df3e['date'], format='%Y/%m/%d %H')


#Filter for Dates
df3e = df3e[(df3e['date'] > '2020/06/18 9:00') & (df3e['date'] <= '2020/07/04')]

#Plot
lw = 2

plt.figure(figsize=(20,4))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d %H:%M'))
plt.gca().xaxis.set_major_locator(mdates.HourLocator(interval=24))
plt.plot(df3e['date'],df3e['EBAM_pm25'], label='EBAM',linewidth=lw, zorder=1)
plt.plot(df3e['date'],df3e['PA_pm25_avg'], label = 'PA-3E',linewidth=lw, zorder=3)
plt.gcf().autofmt_xdate()
plt.title('Hourly E-BAM Concentrations vs Two PurpleAir Sensors at Ohanapocesh Campground: 06/18/2020-07/04/2020', size=18, pad=10)
plt.ylabel('PM2.5 (ug m-3)',size=16, labelpad=10)
plt.xticks(fontsize=13, rotation=30)
plt.yticks(fontsize=13)
plt.legend(fontsize=12)
plt.grid()
# plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import numpy as np
import datetime as dt

df1b = pd.read_csv(r'C:\Users\sph0088\OneDrive - UNT System\MORA\Analysis\E-BAM\EBAM_PA1B_daily.csv')
df1b['date'] = pd.to_datetime(df1b['date'], format='%Y/%m/%d %H')
df3e = pd.read_csv(r'C:\Users\sph0088\OneDrive - UNT System\MORA\Analysis\E-BAM\EBAM_PA3E_daily.csv')
df3e['date'] = pd.to_datetime(df3e['date'], format='%Y/%m/%d %H')

#Filter Date
df1b = df1b[(df1b['date'] > '2020/07/24 16:00') & (df1b['date'] <= '2020/08/04')]
df3e = df3e[(df3e['date'] > '2020/07/24 16:00') & (df3e['date'] <= '2020/08/04')]

#PLOT
lw=3
plt.figure(figsize=(14,6))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.gca().xaxis.set_major_locator(mdates.DayLocator(interval=1))
plt.plot(df1b['date'],df1b['EBAM_pm25'], label='EBAM',linewidth=lw)
plt.plot(df3e['date'],df3e['PA_pm25_avg'], label = 'PA-3E',linewidth=lw)
plt.plot(df1b['date'],df1b['PA_pm25_avg'], label = 'PA-1B',linewidth=lw, alpha=0.5)
plt.gcf().autofmt_xdate()
plt.title('Daily E-BAM & PurpleAir Concentrations at Ohanapocesh Campground: 07/25/20-08/04/20', size=15, pad=10)
plt.ylabel('PM2.5 Concentration (ug m-3)',size=16, labelpad=10)
plt.xticks(fontsize=14, rotation=30)
plt.yticks(fontsize=14)
plt.legend(fontsize=12)
plt.grid()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import numpy as np
import datetime as dt

#Data
df3e = pd.read_csv(r'C:\Users\sph0088\OneDrive - UNT System\MORA\Analysis\E-BAM\EBAM_PA3E_daily.csv')
df3e['date'] = pd.to_datetime(df3e['date'], format='%Y/%m/%d %H')

#Filter Date
df3e = df3e[(df3e['date'] > '2020/06/18 16:00') & (df3e['date'] <= '2020/07/04')]

#Plot
lw=3

plt.figure(figsize=(20,8))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.gca().xaxis.set_major_locator(mdates.DayLocator(interval=1))
plt.plot(df3e['date'],df3e['EBAM_pm25'], label='EBAM',linewidth=lw)
plt.plot(df3e['date'],df3e['PA_pm25_avg'], label = 'PA-3E',linewidth=lw)
plt.gcf().autofmt_xdate()
plt.xticks(fontsize=16, rotation=30)
plt.yticks(fontsize=14)
plt.title('Daily E-BAM & PurpleAir Concentrations at Ohanapocesh Campground: 06/19/20-08/04/20', size=18, pad=10)
plt.ylabel('PM2.5 Concentration (ug m-3)',size=16, labelpad=10)
plt.legend(fontsize=12)
plt.grid()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import numpy as np
import datetime as dt

#Data
df1b = pd.read_csv(r'C:\Users\sph0088\OneDrive - UNT System\MORA\Analysis\E-BAM\EBAM_PA1B_hourly.csv')
df1b['date'] = pd.to_datetime(df1b['date'], format='%Y/%m/%d %H')
df3e = pd.read_csv(r'C:\Users\sph0088\OneDrive - UNT System\MORA\Analysis\E-BAM\EBAM_PA3E_hourly.csv')
df3e['date'] = pd.to_datetime(df3e['date'], format='%Y/%m/%d %H')
dfbam = pd.read_csv(r'C:\Users\sph0088\OneDrive - UNT System\MORA\Analysis\E-BAM\EBAM_PA3E_hourly.csv')
dfbam['date'] = pd.to_datetime(dfbam['date'], format='%Y/%m/%d %H')

#Filter for Dates
# df3e = df3e[(df3e['date'] > '2020/07/24 16:00') & (df3e['date'] <= '2020/08/04')]
# df1b = df1b[(df1b['date'] > '2020/07/24 16:00') & (df1b['date'] <= '2020/08/04')]
dfb1 = df3e[(df3e['date'] > '2020/06/18 16:00') & (df3e['date'] <= '2020/07/04')]
dfb2 = df3e[(df3e['date'] > '2020/07/24 16:00') & (df3e['date'] <= '2020/08/04')]

#Plot
lw = 2

plt.figure(figsize=(20,6))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d %H:%M'))
plt.gca().xaxis.set_major_locator(mdates.HourLocator(interval=24))
plt.plot(dfb1['date'],dfb1['EBAM_pm25'], label='EBAM',linewidth=lw, zorder=1)
plt.plot(dfb2['date'],dfb2['EBAM_pm25'], label='EBAM',linewidth=lw, zorder=1)
plt.plot(dfb1['date'],dfb1['PA_pm25_avg'], label = 'PA-3E',linewidth=lw, zorder=3)
plt.plot(dfb2['date'],dfb2['PA_pm25_avg'], label = 'PA-3E',linewidth=lw, zorder=3)
plt.plot(df1b['date'],df1b['PA_pm25_avg'], label = 'PA-1B', linewidth=lw, zorder=2) #Z order changes the order in which the lines are rendered
plt.gcf().autofmt_xdate()
plt.title('Hourly E-BAM Concentrations vs Two PurpleAir Sensors at Ohanapocesh Campground: Jul-Aug 2020', size=16)
plt.ylabel('PM2.5 Concentration (ug m-3)',size=12)
plt.xticks(fontsize=12, rotation=30)
plt.yticks(fontsize=12)
plt.legend()
plt.grid()
# plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import numpy as np
import datetime as dt
from brokenaxes import brokenaxes


#################### https://stackoverflow.com/questions/5656798/python-matplotlib-is-there-a-way-to-make-a-discontinuous-axis ############################
################# https://matplotlib.org/gallery/subplots_axes_and_figures/broken_axis.html?highlight=broken%20axis ###########################

#Data
df1b = pd.read_csv(r'C:\Users\sph0088\OneDrive - UNT System\MORA\Analysis\E-BAM\EBAM_PA1B_hourly.csv')
df1b['date'] = pd.to_datetime(df1b['date'], format='%Y/%m/%d %H')
df3e = pd.read_csv(r'C:\Users\sph0088\OneDrive - UNT System\MORA\Analysis\E-BAM\EBAM_PA3E_hourly.csv')
df3e['date'] = pd.to_datetime(df3e['date'], format='%Y/%m/%d %H')

exclude_dates = pd.date_range(start='2020/07/04', end='2020/07/24')
df3e = df3e.set_index('date')
df3e = df3e.loc[~df3e.index.isin(exclude_dates)]
df3e

#Filter for Dates
# df3e = df3e[(df3e['date'] > '2020/07/24 16:00') & (df3e['date'] <= '2020/08/04')]
# df1b = df1b[(df1b['date'] > '2020/07/24 16:00') & (df1b['date'] <= '2020/08/04')]

#Plot
lw = 2

plt.figure(figsize=(20,6))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d %H:%M'))
plt.gca().xaxis.set_major_locator(mdates.HourLocator(interval=24))
plt.plot(df3e.index,df3e['EBAM_pm25'], label='EBAM',linewidth=lw, zorder=1)
plt.plot(df3e.index,df3e['PA_pm25_avg'], label = 'PA-3E',linewidth=lw, zorder=3)
# plt.plot(df1b['date'],df1b['PA_pm25_avg'], label = 'PA-1B', linewidth=lw, zorder=2) #Z order changes the order in which the lines are rendered
plt.gcf().autofmt_xdate()
plt.title('Hourly E-BAM Concentrations vs Two PurpleAir Sensors at Ohanapocesh Campground: Jul-Aug 2020', size=16)
plt.ylabel('PM2.5 Concentration (ug m-3)',size=12)
plt.xticks(fontsize=12, rotation=30)
plt.yticks(fontsize=12)
plt.legend()
plt.grid()
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-168-accc8f13f7b2> in <module>
#       4 import numpy as np
#       5 import datetime as dt
# ----> 6 from brokenaxes import brokenaxes
#       7
#       8
#
# ModuleNotFoundError: No module named 'brokenaxes'
